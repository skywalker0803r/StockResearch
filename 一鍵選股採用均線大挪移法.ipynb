# %% [markdown]
# <a href="https://colab.research.google.com/github/skywalker0803r/StockResearch/blob/main/%E4%B8%80%E9%8D%B5%E9%81%B8%E8%82%A1%E6%8E%A1%E7%94%A8%E5%9D%87%E7%B7%9A%E5%A4%A7%E6%8C%AA%E7%A7%BB%E6%B3%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from tqdm import tqdm_notebook as tqdm
url = 'https://gist.githubusercontent.com/skywalker0803r/c8d31d2ab737d2ae1d2b1fa6894831dd/raw/5d8979a3bd46720206c3a96627bf0a12d2cd21c8/StockArmory.py'
exec(requests.get(url).text)
sid_list = getallstocksid()
candidate = []
n = 1000
for sid in tqdm(sid_list[:n]):
  try:
    if health_check_stock(sid) == True:
      print(sid)
      candidate.append(sid)
  except:
    print(f'{sid}:error')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/1000 [00:00<?, ?it/s]
# 1218
# 1312
# 1312
# 4764
# 2103
# 6405
# 5525
# 8462
# Got error from yahoo api for ticker 9108.TW, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - 9108.TW: No data found for this date range, symbol may be delisted
# 9108:error
# Got error from yahoo api for ticker 9116.TW, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - 9116.TW: No data found for this date range, symbol may be delisted
# 9116:error
# Got error from yahoo api for ticker 9116.TW, Error: {'code': 'Not Found', 'description': 'No data found, symbol may be delisted'}
# - 9116.TW: No data found for this date range, symbol may be delisted
# 9116:error
# ...

# %%
import matplotlib.pyplot as plt
n = 60
for sid in candidate:
  df = yf.Ticker(f"{sid}.TW").history(period="max")
  l1 = df.Close.rolling(5).mean()[-n:]
  l2 = df.Close.rolling(10).mean()[-n:]
  l3 = df.Close.rolling(20).mean()[-n:]
  plt.plot(l1)
  plt.plot(l2)
  plt.plot(l3)
  plt.title(sid)
  plt.show()
